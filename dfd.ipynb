# %%
import tensorflow as tf

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "Dataset/train",
    image_size = (224,224),
    batch_size = 8,
    label_mode = "binary"
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "Dataset/validation",
    image_size = (224,224),
    batch_size = 8,
    label_mode = "binary"
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "Dataset/test",
    image_size = (224,224),
    batch_size = 8,
    label_mode = "binary"
)
# Out:
# Found 11633 files belonging to 2 classes.
# Found 2400 files belonging to 2 classes.
# Found 2400 files belonging to 2 classes.

# %%
data_aug = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.2),
    tf.keras.layers.GaussianNoise(0.1)
])

train_ds = train_ds.map(lambda x,y: (data_aug(x, training=True), y))

# %%
train_ds = train_ds.map(lambda x,y: (tf.keras.applications.xception.preprocess_input(x), y))
val_ds = val_ds.map(lambda x,y: (tf.keras.applications.xception.preprocess_input(x), y))
test_ds = test_ds.map(lambda x,y: (tf.keras.applications.xception.preprocess_input(x), y))

# %%
base_model = tf.keras.applications.xception.Xception(
    weights = "imagenet",
    include_top = False,
    input_shape = (224,224,3)
)

base_model.trainable = False

# %%
x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Dense(512, activation="relu")(x) 
x = tf.keras.layers.Dropout(0.5)(x)

x = tf.keras.layers.Dense(256, activation="relu")(x)
x = tf.keras.layers.Dropout(0.5)(x)

output = tf.keras.layers.Dense(1, activation="sigmoid")(x)

model = tf.keras.Model(inputs=base_model.input, outputs=output)

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=0.1),
    metrics = ["accuracy", tf.keras.metrics.AUC(name="auc")]
)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor = "val_loss",
    patience = 3,
    restore_best_weights = True
)

# %%
model.fit(train_ds, validation_data=val_ds, epochs=10, callbacks=[early_stopping])
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769276301.972359   68712 service.cc:152] XLA service 0x75f8880d33b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1769276301.972585   68712 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4050 Laptop GPU, Compute Capability 8.9
# 2026-01-24 17:38:22.141843: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1769276303.262697   68712 cuda_dnn.cc:529] Loaded cuDNN version 91800
# 2026-01-24 17:38:30.515576: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:38:30.724187: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:38:31.467529: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:38:31.678025: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:38:32.471615: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:38:32.701893: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:38:33.393728: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:38:33.656706: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1769276315.505682   68712 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1453/1455 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6359 - auc: 0.6815 - loss: 0.8215
# 2026-01-24 17:39:33.880814: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:34.063435: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:34.250071: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:34.833668: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:35.017854: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:35.784839: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:35.971815: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:36.175967: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:36.384772: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:36.539478: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=0} for conv %cudnn-conv.144 = (f32[1,1024,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,1024,7,7]{3,2,1,0} %bitcast.12488, f32[1024,1,3,3]{3,2,1,0} %bitcast.12495), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1024, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_9_1/block14_sepconv1_1/separable_conv2d/depthwise" source_file="/mnt/d/ML Projects/venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-01-24 17:39:36.588297: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:36.786931: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:37.002009: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:37.215757: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:37.424937: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:37.633255: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:37.641194: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.101846398s
# Trying algorithm eng3{k11=0} for conv %cudnn-conv.144 = (f32[1,1024,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,1024,7,7]{3,2,1,0} %bitcast.12488, f32[1024,1,3,3]{3,2,1,0} %bitcast.12495), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1024, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_9_1/block14_sepconv1_1/separable_conv2d/depthwise" source_file="/mnt/d/ML Projects/venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-01-24 17:39:38.270420: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-24 17:39:38.496300: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6360 - auc: 0.6816 - loss: 0.8214
# 2026-01-24 17:39:44.213129: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1072', 64 bytes spill stores, 64 bytes spill loads
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 97s 53ms/step - accuracy: 0.6758 - auc: 0.7334 - loss: 0.6843 - val_accuracy: 0.6800 - val_auc: 0.7472 - val_loss: 0.6144
# Epoch 2/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 57s 39ms/step - accuracy: 0.7515 - auc: 0.8305 - loss: 0.5548 - val_accuracy: 0.6971 - val_auc: 0.7736 - val_loss: 0.6081
# Epoch 3/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 57s 39ms/step - accuracy: 0.7800 - auc: 0.8600 - loss: 0.5264 - val_accuracy: 0.7054 - val_auc: 0.7788 - val_loss: 0.6044
# Epoch 4/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 57s 39ms/step - accuracy: 0.7911 - auc: 0.8745 - loss: 0.5115 - val_accuracy: 0.6996 - val_auc: 0.7918 - val_loss: 0.6074
# Epoch 5/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 56s 39ms/step - accuracy: 0.8111 - auc: 0.8911 - loss: 0.4920 - val_accuracy: 0.7129 - val_auc: 0.7901 - val_loss: 0.6200
# Epoch 6/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 57s 39ms/step - accuracy: 0.8187 - auc: 0.8987 - loss: 0.4827 - val_accuracy: 0.7196 - val_auc: 0.7936 - val_loss: 0.6144

# %%
base_model.trainable = True

for layer in base_model.layers[:-10]:
    layer.trainable = False

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=0.1),
    metrics = ["accuracy", tf.keras.metrics.AUC(name="auc")]
)

# %%
model.fit(train_ds, validation_data=val_ds, epochs=10, callbacks=[early_stopping])
# Out:
# Epoch 1/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 82s 46ms/step - accuracy: 0.7621 - auc: 0.8449 - loss: 0.5443 - val_accuracy: 0.7633 - val_auc: 0.8458 - val_loss: 0.5419
# Epoch 2/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 57s 39ms/step - accuracy: 0.8374 - auc: 0.9178 - loss: 0.4595 - val_accuracy: 0.7921 - val_auc: 0.8832 - val_loss: 0.5076
# Epoch 3/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 58s 40ms/step - accuracy: 0.8773 - auc: 0.9475 - loss: 0.4141 - val_accuracy: 0.8229 - val_auc: 0.9030 - val_loss: 0.4799
# Epoch 4/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 57s 39ms/step - accuracy: 0.8914 - auc: 0.9592 - loss: 0.3927 - val_accuracy: 0.8217 - val_auc: 0.9084 - val_loss: 0.4766
# Epoch 5/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 57s 39ms/step - accuracy: 0.9049 - auc: 0.9683 - loss: 0.3737 - val_accuracy: 0.8021 - val_auc: 0.9119 - val_loss: 0.5370
# Epoch 6/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 56s 38ms/step - accuracy: 0.9182 - auc: 0.9740 - loss: 0.3585 - val_accuracy: 0.8383 - val_auc: 0.9188 - val_loss: 0.4539
# Epoch 7/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 56s 38ms/step - accuracy: 0.9262 - auc: 0.9786 - loss: 0.3460 - val_accuracy: 0.8421 - val_auc: 0.9228 - val_loss: 0.4752
# Epoch 8/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 56s 38ms/step - accuracy: 0.9291 - auc: 0.9821 - loss: 0.3370 - val_accuracy: 0.8537 - val_auc: 0.9259 - val_loss: 0.4644
# Epoch 9/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 56s 38ms/step - accuracy: 0.9392 - auc: 0.9841 - loss: 0.3282 - val_accuracy: 0.8433 - val_auc: 0.9254 - val_loss: 0.4719

# %%
model.save("dfd_model.keras")
